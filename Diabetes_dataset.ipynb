# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f=pd.read_csv('G:\pima-indians-diabetes.csv')
f.columns
# Out:
# Index(['6', '148', '72', '35', '0', '33.6', '0.627', '50', '1'], dtype='object')

# %%
print(f.shape)  # returns numbers of columns and rows
# Out:
# (767, 9)

# %%
f.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Diabetes                       bool
# dtype: object

# %%
print(f.to_string())
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Diabetes
# 0              1       85             66             29        0  26.6                     0.351   31     False
# 1              8      183             64              0        0  23.3                     0.672   32      True
# 2              1       89             66             23       94  28.1                     0.167   21     False
# 3              0      137             40             35      168  43.1                     2.288   33      True
# 4              5      116             74              0        0  25.6                     0.201   30     False
# 5              3       78             50             32       88  31.0                     0.248   26      True
# 6             10      115              0              0        0  35.3                     0.134   29     False
# ...

# %%
name=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Diabetes']

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   6       767 non-null    int64
#  1   148     767 non-null    int64
#  2   72      767 non-null    int64
#  3   35      767 non-null    int64
#  4   0       767 non-null    int64
#  5   33.6    767 non-null    float64
#  6   0.627   767 non-null    float64
#  7   50      767 non-null    int64
#  8   1       767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
f=pd.read_csv('G:\pima-indians-diabetes.csv',header=0,names=name)
f.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
# 5            3       78             50             32       88  31.0
# 6           10      115              0              0        0  35.3
# 7            2      197             70             45      543  30.5
# 8            8      125             96              0        0   0.0
# 9            4      110             92              0        0  37.6
#
#    DiabetesPedigreeFunction  Age  Diabetes
# 0                     0.351   31         0
# 1                     0.672   32         1
# 2                     0.167   21         0
# ...

# %%
df={1:True,0:False}
f['Diabetes']=f['Diabetes'].map(df)
f.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Diabetes
# 0                     0.351   31     False
# 1                     0.672   32      True
# 2                     0.167   21     False
# 3                     2.288   33      True
# 4                     0.201   30     False

# %%
f.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 762           10      101             76             48      180  32.9
# 763            2      122             70             27        0  36.8
# 764            5      121             72             23      112  26.2
# 765            1      126             60              0        0  30.1
# 766            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diabetes
# 762                     0.171   63     False
# 763                     0.340   27     False
# 764                     0.245   30     False
# 765                     0.349   47      True
# 766                     0.315   23     False

# %%
x=np.array([1, 8, 1, 0, 5])
y=np.array([66, 64, 66, 40, 74])
plt.subplot(2,2,1) 
plt.bar(x, y)
plt.xlabel("Pregnancies")
plt.ylabel("BloodPresure")

x=np.array([1, 8, 1, 0, 5])
y=np.array([85,183,89,137,116])
plt.subplot(2,2,2) 
plt.bar(x, y,color='r')
plt.xlabel("Pregnancies")
plt.ylabel("Glucose")

x=np.array([1, 8, 1, 0, 5])
y=np.array([0,0,94,168,0])
plt.subplot(2,2,3) 
plt.bar(x, y,color='g')
plt.xlabel("Pregnancies")
plt.ylabel("Insulin")

x=np.array([1, 8, 1, 0, 5])
y=np.array([0.351, 0.672, 0.167, 2.288, 0.201])
plt.subplot(2,2,4) 
plt.bar(x, y,color='y')
plt.xlabel("Pregnancies")
plt.ylabel("DiabetesPedigreeFunction")

plt.show()

# %%
x=f['Diabetes'].value_counts()
myexplode = [0.1,0,0.2,0]
plt.pie(x,shadow=True,autopct='%1.1f%%',colors=['g','b'])
plt.show()

# %%
f.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.842243  120.859192      69.101695      20.517601   79.903520
# std       3.370877   31.978468      19.368155      15.954059  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  767.000000                767.000000  767.000000
# mean    31.990482                  0.471674   33.219035
# std      7.889091                  0.331497   11.752296
# min      0.000000                  0.078000   21.000000
# ...

# %%
corrmat = f.corr()
features = corrmat.index
plt.figure(figsize=(5,5))
g=sns.heatmap(f[features].corr(),annot=True,cmap="RdYlGn")

# %%
x=f.corr()
print(x)
plt.figure(figsize=(5,5))
sns.heatmap(x, xticklabels=x.columns, yticklabels=x.columns, annot=False)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128846       0.141197      -0.082495
# Glucose                      0.128846  1.000000       0.152498       0.056381
# BloodPressure                0.141197  0.152498       1.000000       0.207308
# SkinThickness               -0.082495  0.056381       0.207308       1.000000
# Insulin                     -0.072999  0.332383       0.089098       0.437974
# BMI                          0.017518  0.220955       0.281777       0.392553
# DiabetesPedigreeFunction    -0.033927  0.136903       0.041180       0.183498
# Age                          0.544018  0.262408       0.239571      -0.115873
# Diabetes                     0.221087  0.465856       0.064882       0.073265
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.072999  0.017518                 -0.033927
# ...

# %%
sns.pairplot(x)

# %%
f.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128846       0.141197      -0.082495
# Glucose                      0.128846  1.000000       0.152498       0.056381
# BloodPressure                0.141197  0.152498       1.000000       0.207308
# SkinThickness               -0.082495  0.056381       0.207308       1.000000
# Insulin                     -0.072999  0.332383       0.089098       0.437974
# BMI                          0.017518  0.220955       0.281777       0.392553
# DiabetesPedigreeFunction    -0.033927  0.136903       0.041180       0.183498
# Age                          0.544018  0.262408       0.239571      -0.115873
# Diabetes                     0.221087  0.465856       0.064882       0.073265
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.072999  0.017518                 -0.033927
# ...
